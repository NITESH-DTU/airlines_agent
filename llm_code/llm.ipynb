# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override=True)
gemini_api=os.getenv("GEMINI_API_KEY");

# %%
gemini=OpenAI(
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
    api_key=gemini_api
)

# %%
def system_prompt():
    return f"""You are an AI flight booking assistant.

Your job is to help users with:
- searching flights
- booking flights
- handling payments (simulated)
- answering basic airline-related questions

IMPORTANT RULES:
- Do NOT assume real-time data
- Do NOT generate real flight schedules or prices
- Use only placeholder or dummy information when needed

Always:
- Understand the user’s intent clearly
- Respond in a helpful and concise way
- Ask follow-up questions if information is missing (like date, source, destination)

If the user asks about policies (baggage, cancellation, etc.), give general answers, not airline-specific facts.

If you don’t know something, say:
"I’m not sure about that yet, but I can help with booking or searching flights."

Keep responses natural and conversational."""

# %%
message=[{"role":"system","content":system_prompt()},{"role":"user","content":"hi"}]
response=gemini.chat.completions.create(model="gemini-2.5-flash",messages=message)
print(response.choices[0].message.content)
# Out:
# Hello! I'm your AI flight booking assistant. How can I help you today? I can assist with searching for flights, booking them, and answering some basic airline questions.

# %%
# !pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.3.2-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nites\onedrive\desktop\llm_practice\myenv\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading sqlalchemy-2.0.48-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 347.8 kB/s eta 0:00:03
#    ---------------------------------- ----- 1.8/2.1 MB 496.0 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 573.1 kB/s eta 0:00:00
# Downloading greenlet-3.3.2-cp312-cp312-win_amd64.whl (231 kB)
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-3.3.2 sqlalchemy-2.0.48
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sqlalchemy in c:\users\nites\onedrive\desktop\llm_practice\myenv\lib\site-packages (2.0.48)
# Requirement already satisfied: greenlet>=1 in c:\users\nites\onedrive\desktop\llm_practice\myenv\lib\site-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nites\onedrive\desktop\llm_practice\myenv\lib\site-packages (from sqlalchemy) (4.15.0)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
